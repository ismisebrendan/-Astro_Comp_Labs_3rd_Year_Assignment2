# %%
from astropy.io import fits
from astropy import wcs
from astropy import coordinates
from astropy.coordinates import SkyCoord
from astroquery.sdss import SDSS
from astroquery.mast import Observations
from astroquery.mast import MastMissions
from astroquery.mast import Catalogs
from astropy import constants as const
from astropy import units as u
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

# %% [markdown]
# # Exercise A

# %%
red_ant = fits.open('red_antennae.fits')

# %%
red_ant.info()
# Out:
# Filename: red_antennae.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     569   (1055, 1075)   int16 (rescales to float32)

# %%
red_ant[0].header['DATE']
# Out:
# '2005-08-11T21:34:10'

# %%
red_ant[0].data.shape
# Out:
# (1075, 1055)

# %%
plt.imshow(red_ant[0].data, cmap='gray', norm=LogNorm())
plt.colorbar()

# %%
brightest = np.unravel_index(np.argmax(red_ant[0].data), red_ant[0].data.shape)

# %%
plt.imshow(red_ant[0].data, cmap='gray', norm=LogNorm())
plt.colorbar()
plt.hlines(brightest[0], 0, red_ant[0].data.shape[1])
plt.vlines(brightest[1], 0, red_ant[0].data.shape[0])

# %%
plt.imshow(red_ant[0].data, cmap='gray', norm=LogNorm())
plt.colorbar()
plt.ylim([brightest[0]-100, brightest[0]+100])
plt.xlim([brightest[1]-100, brightest[1]+100])
# Out:
# (374.0, 574.0)

# %% [markdown]
# # Exercise 2

# %%
m51_optical = fits.open('m51_optical_R.fits')

# %%
m51_optical.info()
# Out:
# Filename: m51_optical_R.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      34   (2384, 3600)   int16 (rescales to uint16)

# %%
m51_data = m51_optical[0].data

# %%
plt.imshow(m51_data, cmap='gray', norm=LogNorm())
plt.colorbar()

# %%
m51_wcs = wcs.WCS(m51_optical[0].header)
# Out:
# WARNING: FITSFixedWarning: WCSAXES = 2.
# invalid keyvalue. [astropy.wcs.wcs]

# %%
fig = plt.figure()

ax = plt.subplot(projection=m51_wcs)
img = ax.imshow(m51_data, cmap='gray', norm=LogNorm())
fig.colorbar(img, ax=ax)

# %%
c = coordinates.SkyCoord("13h29m52.7s 47d11m43s", frame='icrs')

r = 3 * u.arcminute

sources = SDSS.query_region(c, radius = r)

# %%
sources
# Out:
# <Table length=68>
#        ra              dec               objid         run  rerun camcol field
#     float64          float64             uint64       int32 int32 int32  int32
# ---------------- ---------------- ------------------- ----- ----- ------ -----
# 202.412233226547 47.2233023562291 1237661362908561420  3699   301      6   100
# 202.417022970856 47.2158057581682 1237661362908561473  3699   301      6   100
# 202.447564160515  47.227078435589 1237661362908561433  3699   301      6   100
# 202.446536236938 47.2272157863314 1237661362908561467  3699   301      6   100
# 202.446445486631 47.2272187832606 1237661362908561430  3699   301      6   100
# 202.446137265374 47.2278938796485 1237661362908561432  3699   301      6   100
# 202.418918671018 47.1974803439359 1237661362908561477  3699   301      6   100
# 202.423565762729 47.1979135351773 1237661362908561423  3699   301      6   100
# 202.423570475396 47.1979195927486 1237661362908561450  3699   301      6   100
# 202.430199123592 47.1938321739851 1237661362908561428  3699   301      6   100
#              ...              ...                 ...   ...   ...    ...   ...
# 202.532117019976 47.1888217692187 1237661362908561463  3699   301      6   100
# 202.532117229066 47.1888218862974 1237661362908561427  3699   301      6   100
# 202.432408113287 47.1537603453813 1237661362908561451  3699   301      6   100
# 202.432406158462 47.1537544264534 1237661362908561424  3699   301      6   100
#   202.5207371056 47.1632696295403 1237661362908561475  3699   301      6   100
# 202.480590655247 47.1680197298315 1237661362908561456  3699   301      6   100
# 202.480544159544 47.1679843989206 1237661362908561426  3699   301      6   100
# 202.510030114972 47.1636495655706 1237661362908561446  3699   301      6   100
#  202.44547950556 47.1613676429213 1237661362908561472  3699   301      6   100
# 202.445616410716 47.1612892590829 1237661362908561435  3699   301      6   100

# %%
source_coords = SkyCoord(sources['ra'], sources['dec'], unit="deg")
source_pixels = source_coords.to_pixel(m51_wcs)

# %%
fig = plt.figure()

ax = plt.subplot(projection=m51_wcs)
img = ax.imshow(m51_data, cmap='gray')
fig.colorbar(img, ax=ax)

plt.scatter(source_pixels[0], source_pixels[1], s=5)

# %% [markdown]
# # Exercise C

# %%
hr_data = np.loadtxt('my_data_file.dat')

# %%
masses = hr_data[:,0] * const.M_sun
temp = hr_data[:,1] * u.K
g = 10**hr_data[:,2] * u.cm * u.s**-2
g = g.to(u.m / u.s**2)

# %%
radii = np.sqrt(const.G * masses / g)

# %%
solar_luminosity = u.def_unit('L_sun', u.W * const.L_sun.value, format={'latex': r'L_\odot'})

# %%
def get_luminosity(radius, temperature):
    L = 4 * np.pi * radius**2 * const.sigma_sb * temperature**4
    L = L.to(solar_luminosity)
    return L

# %%
luminosities = get_luminosity(radii, temp)

# %%
luminosities
# Out:
# <Quantity [1.20414521e-04, 2.53545130e-04, 5.55127149e-04, 8.71079269e-04,
#            1.20079605e-03, 1.90496242e-03, 2.71206017e-03, 3.85395582e-03,
#            5.14295799e-03, 8.20075961e-03, 1.17245229e-02, 1.55113139e-02,
#            2.01584800e-02, 2.68172944e-02, 3.62832444e-02, 5.73369774e-02,
#            7.30657316e-02, 1.54368553e-01, 3.41060874e-01, 8.72343877e-01,
#            1.30689243e+00] L_sun>

# %%
plt.scatter(temp, luminosities)
plt.yscale('log')
plt.xscale('log')
plt.gca().invert_xaxis()
plt.xlabel('T [K]')
plt.ylabel(r'L [L$_\odot$]')
plt.title('Hertzsprung-Russell diagram of the stars given')
# Out:
# Text(0.5, 1.0, 'Hertzsprung-Russell diagram of the stars given')

# %% [markdown]
# # PanSTARRS

# %%
missions = MastMissions(mission='TESS')

columns = missions.get_column_list()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\requests\models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File C:\ProgramData\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\ProgramData\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File C:\ProgramData\anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\astroquery\mast\missions.py:247, in MastMissionsClass.get_column_list(self)
#     246 results = requests.get(url)
# --> 247 results = results.json()
#     248 rows = []
#
# File C:\ProgramData\anaconda3\lib\site-packages\requests\models.py:975, in Response.json(self, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[45], line 3
#       1 missions = MastMissions(mission='TESS')
# ----> 3 columns = missions.get_column_list()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\astroquery\utils\class_or_instance.py:25, in class_or_instance.__get__.<locals>.f(*args, **kwds)
#      23 def f(*args, **kwds):
#      24     if obj is not None:
# ---> 25         return self.fn(obj, *args, **kwds)
#      26     else:
#      27         return self.fn(cls, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\astroquery\mast\missions.py:258, in MastMissionsClass.get_column_list(self)
#     256     return data_table
#     257 except Exception:
# --> 258     raise Exception(f"Error occurred while trying to get column list for mission {self.mission}")
#
# Exception: Error occurred while trying to get column list for mission TESS

# %%
columns
# Out:
# <Table length=56>
#         name        ...
#        str22        ...
# ------------------- ...
#          search_pos ...
#   sci_data_set_name ...
#   sci_archive_class ...
#      sci_program_id ...
#        sci_obset_id ...
#          sci_obsnum ...
#          sci_asn_id ...
#        sci_targname ...
#  sci_target_descrip ...
#  sci_broad_category ...
#                 ... ...
#      sci_fov_config ...
# sci_generation_date ...
#    sci_archive_date ...
#    sci_preview_name ...
#        sci_obs_type ...
#       scp_scan_type ...
#            sci_hlsp ...
#             ang_sep ...
#          sci_status ...
#          search_key ...

# %%
Observations.query_region(c, radius = r)
# Out:
# <Table masked=True length=5582>
# intentType obs_collection provenance_name ...  obsid        distance
#   str11        str11           str31      ...   str9        float64
# ---------- -------------- --------------- ... -------- ------------------
#    science           TESS            SPOC ... 27545566                0.0
#    science           TESS            SPOC ... 27347170                0.0
#    science           TESS            SPOC ... 27386992                0.0
#    science           TESS            SPOC ... 83163378                0.0
#    science           TESS            SPOC ... 82448156 144.08140755980807
#    science          SWIFT              -- ...  1628611                0.0
#    science          SWIFT              -- ...  1491576                0.0
#    science          SWIFT              -- ...  1491575                0.0
#    science          SWIFT              -- ...  1493597                0.0
#    science          SWIFT              -- ...  1493598                0.0
#        ...            ...             ... ...      ...                ...
#    science          GALEX             ETS ...   149553 179.51569579130742
#    science          GALEX             ETS ...   149553 179.51569579130742
#    science          GALEX             ETS ...   155367 179.61591778027767
#    science          GALEX             ETS ...   155367 179.61591778027767
#    science           FUSE              -- ...   342719                0.0
#    science           FUSE              -- ...   347241 35.582431590691435
#    science           FUSE              -- ...   343725  37.92515769510467
#    science           FUSE              -- ...   347242  83.94242268063144
#    science           FUSE              -- ...   347243 110.34287613477731
#    science           FUSE              -- ...   342720 131.59055730839324
